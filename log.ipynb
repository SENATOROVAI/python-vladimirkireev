# %% [markdown]
# 26.08.2023 - the first lesson
#
# 1. Урок начался с изучения github, как я в дальнешем понял, git клиент и работа с локалкой, а github с сайтом.
# Мы изучали возможности ресурса, который позволяет скачивать репозитарии других людей (git clone), выгружать свои (push), отслеживать работу владельца, сколько он времени работает с github. Поработали с основными инструментами, например fork переносит файлы компании или человека в мой профиль, что дает мне возможность смотреть, редактировать или оставлять комментарии с кодом. Кнопка star является что-то вроде like в социальных сетях, помогает продвижению и в целом оценивает популярность и ценный вес поста.
#
# Чтобы принимать домашку и в целом файлы нужно нажать git pull
#
# После изменений или работы нужно зафиксировать данные для этого использует commit, он будет локальный пока не нажать push
#
# Главным достоинством является возможность взаимодействия с другими участниками комманды при работе с проектами.
#
# Для того чтобы иметь возможность работы с чужими репозитариями нужно делать pull request и ждать одобрения от владельца.
#
# 2. Мы установили виртуальный python. Venv это локальный python, позволяющий тестировать и делать что хочешь с ним, не травмируя главный python. Как я понял, под каждый новый проект нужно создавать виртульное окружение.
#
# 3. Я узнал что есть менеджер пакетов pip, позволяет управлять, изменять, модули и зависимости. Например я передаю данные своего проекта другому программисту, чтобы он понимал с какими модулями я работал и быстро их установил, ему будет достаточно установить модули через комманду ниже и продолжить взаимодействие с проектом.
#
# Для создания списка пишем комманду
# !pip freeze > requirements.txt  (будет сложно запомнить квадратную скобку)
# Для установки команда
# !pip install -r requirements.txt
#
# 4. С помощью "!" можно работать напрямую в терминале
#
# 5. Команда python -m venv venv, написанная в терминале позволяет создать папку venv, как я понял, если поставить "!" можно не писать сразу из Vcode
#
# 6. venv\Scripts\activate активирует работу venv (venv\sc+tab\a+tab)
#
# 7. Руслан помог установить различные модули облегчающие работу в python, такие как Black (исправляет ошибки основываясь на Flake8), Flake8 (подсвечивает ошибки при работе с кодом), напоминают расширения из google chrome :)
#
#
# 03.09.2023 - second lesson
#
# 1. Мы повторили пройденные материалы по github, что явно было необходимо сделать, многое забыл, что-то обновил для себя в сознании.
# 2. Узнал, как добавлять pdf и другие файлы в github, нужно просто перекинуть файлы в категорию. Таким образом я буду сдавать домашку.
#
# 3. Установили Anaconda, это еще один менеджер пакетов, более мощный, как я понял более заточенный под DS. При установки надо ставить галочку, чтобы указать и соединить путь к пайтону, так программа встраивается в VSCODE.
#
# 4. Разобрали и повторили простую матиматику в python, особое внимание надо уделить делению по модулю % (когда python выводит остаток от деления), возведение в степень **.
#
# 5. Булевые операции на правду и ложь с названиями, которые я сразу точно не запомню - Конъюкция (умножение "and"), Дизъюкция (сложение "or") и Инверсия (отрицание "not")
#
# 6. Далее пошла тема, которая требует более глубокого и последовательного изучения. Руслан мне рассказал об этом поверхностно для общего понимания. Из того, что я хорошо запомнил -  в python есть функции, объекты и классы. Класс задает родительские условия, например функции, которые потом можно применять к другим объектам, как к дочерним.

# %% [markdown]
# 16.09.2023
#
# Я понемного восстанавливаю знания школьной математики, и много где изучаю, что пропускал :)
#
# В этом уроке изучали векторы, и немного алгебры.
#
# 1. Вектор это отрезок имеющий хвост и голову, голова для простого восприятия является наконечником стрелы.
# 2. Базис вектор - вектор начинается из нулевых точек
# 3. Ортоганальность - перпендикулярность. Например говорят ортогональные векторы.
# 4. Колленеарностный векторы - значит параллельные
# 5. Корни, у меня тут пробел в знаниях, сегодня мы это подтянули, у меня будет домашка по корням, я их еще точно наверстаю и нарешаю
# 6. Scalar (Скаляр) - простое число
# 7. Numpy. Самое интересное это применение теоретических знаний на практике, для серьзной работы, мы должны использовать numpy, он включает множество модулей для работы. Сегодня я вывел простой отрезок в визуал.
#
# import numpy as np - импорт модуля numpy, as np - означает, что далее мы будем обращаться к numpy сокращенно np
# import matplotlib.pyplot as plt #.pyplot . означает конкретный модуль, как я понял matplotlib.pyplot позволяет визуализировать все в графике
# v = np.array([2, -1]) -  создаем массив данных
# plt.plot([0, v[0]],[0, v[1]]) - задаем параметры координат для наших х и y
# plt.axis([-3, 3, -3, 3]) - задаем параметры рабочего поля
# plt.grid() - добавляем сетку
#
# Ну и сухие данные
#
# e = 2.71, используется в натуральныльных лагорифмах
# [a, b) - первая квадратная скобка означает не строгое, а круглая скобка около b строгое.(Руслан помоги вспомнить) Что строгое, а что не строгое не помню. Понимаю, лишь то, что а не включает себя в отрезок, b включает.

# %%
21.10.2023

1. Немного вспомнили git, покапавшись в репах наших коллег.

2. Пробовали решать задачи на leedcode. Для меня сложностью является понимание работы функций в python,
Мы попробовали решить простейший пример задачи, изучая функцию. За один раз в голове это, конечно не кладывается.
Надо выполнить несколько повторений для понимание работы. 

Дополнительно, я узнаю о методах функций. Которых огромное множество, скорее всего всеми
никто не пользуется, но набор определенных и популярных знать необходимо.

Еще я попробовать ф строку. Ее преимуществом является простота внедрения в основной текстовый блок
любых элементов кода.
